# %%
import pandas as pd

# %%
## transform to a Series
Pokemon = pd.read_csv('pokemon.csv',usecols=['Pokemon'],index_col= 'Pokemon',squeeze= True)

# %%
P= pd.read_csv('pokemon.csv',index_col= 'Pokemon',squeeze= True)

# %%
P.value_counts()
# Out:
# Water       105
# Normal       93
# Grass        66
# Bug          63
# Psychic      47
# Fire         47
# Rock         41
# Electric     36
# Ground       30
# Poison       28
# Dark         28
# Fighting     25
# Dragon       24
# Ghost        23
# Ice          23
# Steel        22
# Fairy        17
# Flying        3
# Name: Type, dtype: int64

# %%
P.value_counts().sum()
# Out:
# 721

# %%
nba = pd.read_csv('nba.csv')

# %%
nba.head(3)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN

# %%
#Insert a new column
nba.insert(5,column = 'League', value = 'NBA')

# %%
nba.head(5)
# Out:
#             Name            Team  Number Position   Age League Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    NBA    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    NBA    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    NBA    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    NBA    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0    NBA   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba['Country']= 'USA'

# %%
nba.head(2)
# Out:
#             Name            Team  Number Position   Age League Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    NBA    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    NBA    6-6   235.0
#
#      College     Salary Country
# 0      Texas  7730337.0     USA
# 1  Marquette  6796117.0     USA

# %%
nba['Team'].value_counts()
# Out:
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Los Angeles Lakers        15
# Houston Rockets           15
# Cleveland Cavaliers       15
# Boston Celtics            15
# Los Angeles Clippers      15
# Utah Jazz                 15
# Charlotte Hornets         15
# Chicago Bulls             15
# Philadelphia 76ers        15
# San Antonio Spurs         15
# Toronto Raptors           15
# Sacramento Kings          15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Indiana Pacers            15
# Atlanta Hawks             15
# Detroit Pistons           15
# Washington Wizards        15
# Phoenix Suns              15
# Denver Nuggets            15
# Brooklyn Nets             15
# Dallas Mavericks          15
# Miami Heat                15
# Golden State Warriors     15
# Minnesota Timberwolves    14
# Orlando Magic             14
# Name: Team, dtype: int64

# %%
nba.dropna(how = 'all')
# Out:
#               Name            Team  Number Position   Age League Height  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    NBA    6-2
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    NBA    6-6
# 2     John Holland  Boston Celtics    30.0       SG  27.0    NBA    6-5
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    NBA    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0    NBA   6-10
# ..             ...             ...     ...      ...   ...    ...    ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    NBA    6-3
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    NBA    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    NBA    7-3
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    NBA    7-0
# 457            NaN             NaN     NaN      NaN   NaN    NBA    NaN
#
#      Weight            College     Salary Country
# 0     180.0              Texas  7730337.0     USA
# ...

# %%
nba.dropna(how = 'any')
# Out:
#               Name            Team  Number Position   Age League Height  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    NBA    6-2
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    NBA    6-6
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    NBA    6-5
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    NBA    6-8
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    NBA    7-0
# ..             ...             ...     ...      ...   ...    ...    ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    NBA    6-8
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    NBA    6-6
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0    NBA   6-10
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    NBA    6-3
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    NBA    7-0
#
#      Weight        College     Salary Country
# 0     180.0          Texas  7730337.0     USA
# ...

# %%
nba.dropna(how = 'any',inplace = 'True')

# %%
nba.dropna(subset = ['Salary'])
# Out:
#               Name            Team  Number Position   Age League Height  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    NBA    6-2
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    NBA    6-6
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    NBA    6-5
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0    NBA   6-10
# 5     Amir Johnson  Boston Celtics    90.0       PF  29.0    NBA    6-9
# ..             ...             ...     ...      ...   ...    ...    ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0    NBA   6-10
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    NBA    6-3
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    NBA    6-1
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    NBA    7-3
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    NBA    7-0
#
#      Weight        College      Salary Country
# 0     180.0          Texas   7730337.0     USA
# ...

# %%
nba['Salary'].fillna(0)
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            0.0
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457          0.0
# Name: Salary, Length: 458, dtype: float64

# %%
nba.head(6)
# Out:
#             Name            Team  Number Position   Age League Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    NBA    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    NBA    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    NBA    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    NBA    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0    NBA   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    NBA    6-9   240.0
#
#              College      Salary Country
# 0              Texas   7730337.0     USA
# 1          Marquette   6796117.0     USA
# 2  Boston University         NaN     USA
# 3      Georgia State   1148640.0     USA
# 4                NaN   5000000.0     USA
# 5                NaN  12000000.0     USA

# %%
nba_df = nba.dropna(how='any')

# %%
nba_df
# Out:
#               Name            Team  Number Position   Age League Height  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    NBA    6-2
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    NBA    6-6
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    NBA    6-5
# 6    Jordan Mickey  Boston Celtics    55.0       PF  21.0    NBA    6-8
# 7     Kelly Olynyk  Boston Celtics    41.0        C  25.0    NBA    7-0
# ..             ...             ...     ...      ...   ...    ...    ...
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    NBA    6-8
# 451  Chris Johnson       Utah Jazz    23.0       SF  26.0    NBA    6-6
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0    NBA   6-10
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    NBA    6-3
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    NBA    7-0
#
#      Weight        College     Salary Country
# 0     180.0          Texas  7730337.0     USA
# ...

# %%
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    object
#  2   Number    364 non-null    float64
#  3   Position  364 non-null    object
#  4   Age       364 non-null    float64
#  5   League    364 non-null    object
#  6   Height    364 non-null    object
#  7   Weight    364 non-null    float64
#  8   College   364 non-null    object
#  9   Salary    364 non-null    float64
#  10  Country   364 non-null    object
# dtypes: float64(4), object(7)
# memory usage: 34.1+ KB

# %%
nba_df["Salary"].fillna(0,inplace= True)

# %%
nba_df["Position"].nunique()
# Out:
# 5

# %%
nba_df["Salary"].astype("int")
# Out:
# 0      7730337
# 1      6796117
# 3      1148640
# 6      1170960
# 7      2165160
#         ...
# 449    1348440
# 451     981348
# 452    2239800
# 453    2433333
# 456     947276
# Name: Salary, Length: 364, dtype: int64

# %%
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    object
#  2   Number    364 non-null    float64
#  3   Position  364 non-null    object
#  4   Age       364 non-null    float64
#  5   League    364 non-null    object
#  6   Height    364 non-null    object
#  7   Weight    364 non-null    float64
#  8   College   364 non-null    object
#  9   Salary    364 non-null    int64
#  10  Country   364 non-null    object
# dtypes: float64(3), int64(1), object(7)
# memory usage: 34.1+ KB

# %%
nba_df["Position"].astype("category")
# Out:
# 0      PG
# 1      SF
# 3      SG
# 6      PF
# 7       C
#        ..
# 449    SG
# 451    SF
# 452    PF
# 453    PG
# 456     C
# Name: Position, Length: 364, dtype: category
# Categories (5, object): ['C', 'PF', 'PG', 'SF', 'SG']

# %%
nba_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 364 entries, 0 to 456
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      364 non-null    object
#  1   Team      364 non-null    object
#  2   Number    364 non-null    float64
#  3   Position  364 non-null    category
#  4   Age       364 non-null    float64
#  5   League    364 non-null    object
#  6   Height    364 non-null    object
#  7   Weight    364 non-null    float64
#  8   College   364 non-null    object
#  9   Salary    364 non-null    int64
#  10  Country   364 non-null    object
# dtypes: category(1), float64(3), int64(1), object(6)
# memory usage: 31.8+ KB

# %%
nba_df.sort_values(["Team","Name"],ascending = [True,False])
# Out:
#                  Name                Team  Number Position   Age League  \
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0       SG  24.0    NBA
# 315      Paul Millsap       Atlanta Hawks     4.0       PF  31.0    NBA
# 319        Mike Scott       Atlanta Hawks    32.0       PF  27.0    NBA
# 316      Mike Muscala       Atlanta Hawks    31.0       PF  24.0    NBA
# 317   Lamar Patterson       Atlanta Hawks    13.0       SG  24.0    NBA
# ..                ...                 ...     ...      ...   ...    ...
# 374        JJ Hickson  Washington Wizards    21.0        C  27.0    NBA
# 380    Garrett Temple  Washington Wizards    17.0       SG  30.0    NBA
# 372       Drew Gooden  Washington Wizards    90.0       PF  34.0    NBA
# 369      Bradley Beal  Washington Wizards     3.0       SG  22.0    NBA
# 368     Alan Anderson  Washington Wizards     6.0       SG  33.0    NBA
#
#     Height  Weight               College    Salary Country
# ...

# %%
df_emp = pd.read_csv('employees.csv',parse_dates = ["Start Date","Last Login Time"])

# %%
df_emp.head(5)
# Out:
#   First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06 2021-06-15 12:42:00   97308    6.945
# 1     Thomas    Male 1996-03-31 2021-06-15 06:53:00   61933    4.170
# 2      Maria  Female 1993-04-23 2021-06-15 11:17:00  130590   11.858
# 3      Jerry    Male 2005-03-04 2021-06-15 13:00:00  138705    9.340
# 4      Larry    Male 1998-01-24 2021-06-15 16:47:00  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(4)
# memory usage: 62.6+ KB

# %%
df_emp["Team"] =  df_emp["Team"].astype("category")

# %% [markdown]
# df_emp.info()

# %%
df_emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   datetime64[ns]
#  3   Last Login Time    1000 non-null   datetime64[ns]
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    category
# dtypes: category(1), datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 56.2+ KB

# %%
df_emp[df_emp["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-06-15 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2021-06-15 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2021-06-15 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2021-06-15 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2021-06-15 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2021-06-15 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2021-06-15 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2021-06-15 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2021-06-15 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2021-06-15 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
df_emp[df_emp["Team"].isin(["Marketing","Finance"])]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-06-15 12:42:00   97308    6.945
# 2        Maria  Female 1993-04-23 2021-06-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-06-15 13:00:00  138705    9.340
# 7          NaN  Female 2015-07-20 2021-06-15 10:43:00   45906   11.598
# 14    Kimberly  Female 1999-01-14 2021-06-15 07:13:00   41426   14.543
# ..         ...     ...        ...                 ...     ...      ...
# 987     Gloria  Female 2014-12-08 2021-06-15 05:08:00  136709   10.331
# 991       Rose  Female 2002-08-25 2021-06-15 05:12:00  134505   11.051
# 992    Anthony    Male 2011-10-16 2021-06-15 08:35:00  112769   11.625
# 994     George    Male 2013-06-21 2021-06-15 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2021-06-15 06:30:00   42392   19.675
#
#     Senior Management       Team
# 0                True  Marketing
# 2               False    Finance
# ...

# %%
df_emp[df_emp["Gender"].notnull()]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male 1993-08-06 2021-06-15 12:42:00   97308    6.945
# 1       Thomas    Male 1996-03-31 2021-06-15 06:53:00   61933    4.170
# 2        Maria  Female 1993-04-23 2021-06-15 11:17:00  130590   11.858
# 3        Jerry    Male 2005-03-04 2021-06-15 13:00:00  138705    9.340
# 4        Larry    Male 1998-01-24 2021-06-15 16:47:00  101004    1.389
# ..         ...     ...        ...                 ...     ...      ...
# 994     George    Male 2013-06-21 2021-06-15 17:47:00   98874    4.479
# 996    Phillip    Male 1984-01-31 2021-06-15 06:30:00   42392   19.675
# 997    Russell    Male 2013-05-20 2021-06-15 12:39:00   96914    1.421
# 998      Larry    Male 2013-04-20 2021-06-15 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2021-06-15 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# ...

# %%
df_emp[df_emp["Last Login Time"].between("8:00AM","12:00PM")]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2021-06-15 11:17:00  130590   11.858
# 7          NaN  Female 2015-07-20 2021-06-15 10:43:00   45906   11.598
# 10      Louise  Female 1980-08-12 2021-06-15 09:01:00   63241   15.132
# 18       Diana  Female 1981-10-23 2021-06-15 10:27:00  132940   19.082
# 33        Jean  Female 1993-12-18 2021-06-15 09:07:00  119082   16.180
# ..         ...     ...        ...                 ...     ...      ...
# 963        Ann  Female 1994-09-23 2021-06-15 11:15:00   89443   17.940
# 977      Sarah  Female 1995-12-04 2021-06-15 09:16:00  124566    5.949
# 982       Rose  Female 1982-04-06 2021-06-15 10:43:00   91411    8.639
# 988      Alice  Female 2004-10-05 2021-06-15 09:34:00   47638   11.209
# 992    Anthony    Male 2011-10-16 2021-06-15 08:35:00  112769   11.625
#
#     Senior Management                  Team
# 2               False               Finance
# ...

# %%
df_emp[~df_emp["First Name"].duplicated(keep = False)].sort_values("First Name")
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 8       Angela  Female 2005-11-22 2021-06-15 06:29:00   95570   18.523
# 688      Brian    Male 2007-04-07 2021-06-15 22:47:00   93901   17.821
# 190      Carol  Female 1996-03-19 2021-06-15 03:39:00   57783    9.129
# 887      David    Male 2009-12-05 2021-06-15 08:48:00   92242   15.407
# 5       Dennis    Male 1987-04-18 2021-06-15 01:35:00  115163   10.125
# 495     Eugene    Male 1984-05-24 2021-06-15 10:54:00   81077    2.117
# 33        Jean  Female 1993-12-18 2021-06-15 09:07:00  119082   16.180
# 832      Keith    Male 2003-02-12 2021-06-15 15:02:00  120672   19.467
# 291      Tammy  Female 1984-11-11 2021-06-15 10:30:00  132839   17.463
#
#     Senior Management                  Team
# 8                True           Engineering
# 688              True                 Legal
# 190             False               Finance
# 887             False                 Legal
# ...

# %%
len(df_emp["Team"].unique())
# Out:
# 11

# %%
df_emp["Team"].nunique()
# Out:
# 10

# %%
bond = pd.read_csv('jamesbond.csv')

# %%
bond.head(5)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.set_index("Film",inplace=True)

# %%
bond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, Dr. No to Spectre
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               26 non-null     int64
#  1   Actor              26 non-null     object
#  2   Director           26 non-null     object
#  3   Box Office         26 non-null     float64
#  4   Budget             26 non-null     float64
#  5   Bond Actor Salary  18 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 1.4+ KB

# %%
bond.loc["Goldfinger"]
# Out:
# Year                         1964
# Actor                Sean Connery
# Director             Guy Hamilton
# Box Office                  820.4
# Budget                       18.6
# Bond Actor Salary             3.2
# Name: Goldfinger, dtype: object

# %%
"Gold" in bond.index
# Out:
# False

# %%
bond.iloc[[1,5,10]]
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# You Only Live Twice    1967  Sean Connery  Lewis Gilbert       514.2    59.9
# The Spy Who Loved Me   1977   Roger Moore  Lewis Gilbert       533.0    45.1
#
#                        Bond Actor Salary
# Film
# From Russia with Love                1.6
# You Only Live Twice                  4.4
# The Spy Who Loved Me                 NaN

# %%
bond.iloc[:7,:3]
# Out:
#                                  Year           Actor       Director
# Film
# Dr. No                           1962    Sean Connery  Terence Young
# From Russia with Love            1963    Sean Connery  Terence Young
# Goldfinger                       1964    Sean Connery   Guy Hamilton
# Thunderball                      1965    Sean Connery  Terence Young
# Casino Royale                    1967     David Niven     Ken Hughes
# You Only Live Twice              1967    Sean Connery  Lewis Gilbert
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt

# %%
bond.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
bond.columns= ['Film','Release Date','Actor','Director','Box Office','Budget','Bond Actor Salary']

# %%
bond.head()
# Out:
#                     Film  Release Date         Actor       Director  \
# 0                 Dr. No          1962  Sean Connery  Terence Young
# 1  From Russia with Love          1963  Sean Connery  Terence Young
# 2             Goldfinger          1964  Sean Connery   Guy Hamilton
# 3            Thunderball          1965  Sean Connery  Terence Young
# 4          Casino Royale          1967   David Niven     Ken Hughes
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# 3       848.1    41.9                4.7
# 4       315.0    85.0                NaN

# %%
chicago = pd.read_csv("Chicago.csv")

# %%
chicago.head()
# Out:
#                   Name            Position Title        Department  \
# 0      AARON,  ELVIA J          WATER RATE TAKER       WATER MGMNT
# 1    AARON,  JEFFERY M            POLICE OFFICER            POLICE
# 2       AARON,  KARINA            POLICE OFFICER            POLICE
# 3  AARON,  KIMBERLEI R  CHIEF CONTRACT EXPEDITER  GENERAL SERVICES
# 4  ABAD JR,  VICENTE M         CIVIL ENGINEER IV       WATER MGMNT
#
#   Employee Annual Salary
# 0              $90744.00
# 1              $84450.00
# 2              $84450.00
# 3              $89880.00
# 4             $106836.00

# %%
chicago["Name"].str.title()
# Out:
# 0            Aaron,  Elvia J
# 1          Aaron,  Jeffery M
# 2             Aaron,  Karina
# 3        Aaron,  Kimberlei R
# 4        Abad Jr,  Vicente M
#                 ...
# 32058     Zygowicz,  Peter J
# 32059      Zymantas,  Mark E
# 32060    Zyrkowski,  Carlo E
# 32061    Zyskowski,  Dariusz
# 32062                    NaN
# Name: Name, Length: 32063, dtype: object

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32063 entries, 0 to 32062
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Name                    32062 non-null  object
#  1   Position Title          32062 non-null  object
#  2   Department              32062 non-null  object
#  3   Employee Annual Salary  32062 non-null  object
# dtypes: object(4)
# memory usage: 1002.1+ KB

# %%
chicago.columns.str.upper()
# Out:
# Index(['NAME', 'POSITION TITLE', 'DEPARTMENT', 'EMPLOYEE ANNUAL SALARY'], dtype='object')

# %%
chicago["Name"].str.split(",").str.get(0).str.title().value_counts()
# Out:
# Williams      293
# Johnson       244
# Smith         241
# Brown         185
# Jones         183
#              ...
# Shackleton      1
# Bybee           1
# Bensen          1
# Kardasz         1
# Mc Kendry       1
# Name: Name, Length: 13829, dtype: int64

# %%
chicago[["First Name","Last Name"]] = chicago["Name"].str.split(",",expand = True)

# %%
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary  \
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00
#
#   First Name    Last Name
# 0      AARON      ELVIA J
# 1      AARON    JEFFERY M
# 2      AARON       KARINA

# %%
sales = pd.read_csv("salesmen.csv", parse_dates = ["Date"])

# %%
sales.head()
# Out:
#         Date Salesman  Revenue
# 0 2016-01-01      Bob     7172
# 1 2016-01-02      Bob     6362
# 2 2016-01-03      Bob     5982
# 3 2016-01-04      Bob     7917
# 4 2016-01-05      Bob     7837

# %%
sales.pivot(index = "Date", columns = "Salesman", values = "Revenue")
# Out:
# Salesman     Bob  Dave   Jeb  Oscar  Ronald
# Date
# 2016-01-01  7172  1864  4430   5250    2639
# 2016-01-02  6362  8278  8026   8661    4951
# 2016-01-03  5982  4226  5188   7075    2703
# 2016-01-04  7917  3868  3144   2524    4258
# 2016-01-05  7837  2287   938   2793    7771
# ...          ...   ...   ...    ...     ...
# 2016-12-27  2045  2843  6666    835    2981
# 2016-12-28   100  8888  1243   3073    6129
# 2016-12-29  4115  9490  3498   6424    7662
# 2016-12-30  2577  3594  8858   7088    2570
# 2016-12-31  3845  6830  9717   8408    2619
#
# [366 rows x 5 columns]

# %%
food = pd.read_csv("foods.csv")

# %%
food.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
food.pivot_table(values = "Spend",index = ["Gender","City"],columns = "Item",aggfunc = "sum")
# Out:
# Item                  Burger  Burrito  Chalupa    Donut  Ice Cream    Sushi
# Gender City
# Female New York      1239.04   978.95   876.58  1446.78    1521.62  1480.29
#        Philadelphia  1639.24  1458.76  1673.33  1639.26    1479.22  1742.88
#        Stamford      1216.02  1820.11  1602.35  1656.96    1032.03  1459.91
# Male   New York      1294.09  1399.40  1227.77  1345.27    1603.63  1396.15
#        Philadelphia   938.18  1312.93  1114.23  1249.36    2191.27  1395.88
#        Stamford      1439.16  1300.29  1150.26  1421.13    1059.22  1267.82

# %%
q_sales = pd.read_csv("quarters.csv")

# %%
q_sales.head()
# Out:
#   Salesman      Q1      Q2      Q3      Q4
# 0    Boris  602908  233879  354479   32704
# 1      Bob   43790  514863  297151  544493
# 2    Tommy  392668  113579  430882  247231
# 3   Travis  834663  266785  749238  570524
# 4   Donald  580935  411379  110390  651572

# %%
q_sales.melt(id_vars = "Salesman", var_name = "Quarters",value_name = "Revenue")
# Out:
#    Salesman Quarters  Revenue
# 0     Boris       Q1   602908
# 1       Bob       Q1    43790
# 2     Tommy       Q1   392668
# 3    Travis       Q1   834663
# 4    Donald       Q1   580935
# 5       Ted       Q1   656644
# 6       Jeb       Q1   486141
# 7     Stacy       Q1   479662
# 8    Morgan       Q1   992673
# 9     Boris       Q2   233879
# 10      Bob       Q2   514863
# 11    Tommy       Q2   113579
# 12   Travis       Q2   266785
# 13   Donald       Q2   411379
# 14      Ted       Q2    70803
# 15      Jeb       Q2   600753
# 16    Stacy       Q2   742806
# 17   Morgan       Q2   879183
# 18    Boris       Q3   354479
# 19      Bob       Q3   297151
# 20    Tommy       Q3   430882
# 21   Travis       Q3   749238
# 22   Donald       Q3   110390
# 23      Ted       Q3   375948
# 24      Jeb       Q3   742716
# 25    Stacy       Q3   770712
# 26   Morgan       Q3    37945
# 27    Boris       Q4    32704
# 28      Bob       Q4   544493
# 29    Tommy       Q4   247231
# ...

# %%
fortune = pd.read_csv("fortune1000.csv", index_col = "Rank")
sector = fortune.groupby("Sector")
fortune.head()
# Out:
#                  Company       Sector  \
# Rank
# 1                Walmart    Retailing
# 2            Exxon Mobil       Energy
# 3                  Apple   Technology
# 4     Berkshire Hathaway   Financials
# 5               McKesson  Health Care
#
#                                       Industry           Location  Revenue  \
# Rank
# 1                        General Merchandisers    Bentonville, AR   482130
# 2                           Petroleum Refining         Irving, TX   246204
# 3                  Computers, Office Equipment      Cupertino, CA   233715
# 4     Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 5                     Wholesalers: Health Care  San Francisco, CA   181241
#
#       Profits  Employees
# Rank
# 1       14694    2300000
# 2       16150      75600
# 3       53394     110000
# 4       24083     331000
# 5        1476      70400

# %%
type(sector)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
sector.size()
# Out:
# Sector
# Aerospace & Defense              20
# Apparel                          15
# Business Services                51
# Chemicals                        30
# Energy                          122
# Engineering & Construction       26
# Financials                      139
# Food and Drug Stores             15
# Food, Beverages & Tobacco        43
# Health Care                      75
# Hotels, Resturants & Leisure     25
# Household Products               28
# Industrials                      46
# Materials                        43
# Media                            25
# Motor Vehicles & Parts           24
# Retailing                        80
# Technology                      102
# Telecommunications               15
# Transportation                   36
# Wholesalers                      40
# dtype: int64

# %%
fortune["Sector"].value_counts()
# Out:
# Financials                      139
# Energy                          122
# Technology                      102
# Retailing                        80
# Health Care                      75
# Business Services                51
# Industrials                      46
# Food, Beverages & Tobacco        43
# Materials                        43
# Wholesalers                      40
# Transportation                   36
# Chemicals                        30
# Household Products               28
# Engineering & Construction       26
# Hotels, Resturants & Leisure     25
# Media                            25
# Motor Vehicles & Parts           24
# Aerospace & Defense              20
# Food and Drug Stores             15
# Telecommunications               15
# Apparel                          15
# Name: Sector, dtype: int64

# %%
sector.get_group("Energy")
# Out:
#                         Company  Sector                      Industry  \
# Rank
# 2                   Exxon Mobil  Energy            Petroleum Refining
# 14                      Chevron  Energy            Petroleum Refining
# 30                  Phillips 66  Energy            Petroleum Refining
# 32                Valero Energy  Energy            Petroleum Refining
# 42           Marathon Petroleum  Energy            Petroleum Refining
# ...                         ...     ...                           ...
# 981                  WPX Energy  Energy  Mining, Crude-Oil Production
# 983    Adams Resources & Energy  Energy            Petroleum Refining
# 995                   EP Energy  Energy  Mining, Crude-Oil Production
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
# 997   Portland General Electric  Energy   Utilities: Gas and Electric
#
#              Location  Revenue  Profits  Employees
# Rank
# 2          Irving, TX   246204    16150      75600
# ...

# %%
sector.sum()
# Out:
#                               Revenue  Profits  Employees
# Sector
# Aerospace & Defense            357940    28742     968057
# Apparel                         95968     8236     346397
# Business Services              272195    28227    1361050
# Chemicals                      243897    22628     463651
# Energy                        1517809   -73447    1188927
# Engineering & Construction     153983     5304     406708
# Financials                    2217159   260209    3359948
# Food and Drug Stores           483769    16759    1395398
# Food, Beverages & Tobacco      555967    51417    1211632
# Health Care                   1614707   106114    2678289
# Hotels, Resturants & Leisure   169546    20697    2484245
# Household Products             234737    14428     646038
# Industrials                    497581    20764    1545229
# Materials                      259145     4428     638123
# Media                          220764    24347     550314
# ...

# %%
fortune["Revenue"].sum()
# Out:
# 13535525

# %%
sector.agg({"Revenue":"sum",
            "Profits":"mean"})
# Out:
#                               Revenue      Profits
# Sector
# Aerospace & Defense            357940  1437.100000
# Apparel                         95968   549.066667
# Business Services              272195   553.470588
# Chemicals                      243897   754.266667
# Energy                        1517809  -602.024590
# Engineering & Construction     153983   204.000000
# Financials                    2217159  1872.007194
# Food and Drug Stores           483769  1117.266667
# Food, Beverages & Tobacco      555967  1195.744186
# Health Care                   1614707  1414.853333
# Hotels, Resturants & Leisure   169546   827.880000
# Household Products             234737   515.285714
# Industrials                    497581   451.391304
# Materials                      259145   102.976744
# Media                          220764   973.880000
# Motor Vehicles & Parts         482540  1079.083333
# Retailing                     1465076   597.875000
# ...

# %%
sector.agg(["size","sum","mean"])
# Out:
#                              Revenue                        Profits          \
#                                 size      sum          mean    size     sum
# Sector
# Aerospace & Defense               20   357940  17897.000000      20   28742
# Apparel                           15    95968   6397.866667      15    8236
# Business Services                 51   272195   5337.156863      51   28227
# Chemicals                         30   243897   8129.900000      30   22628
# Energy                           122  1517809  12441.057377     122  -73447
# Engineering & Construction        26   153983   5922.423077      26    5304
# Financials                       139  2217159  15950.784173     139  260209
# Food and Drug Stores              15   483769  32251.266667      15   16759
# Food, Beverages & Tobacco         43   555967  12929.465116      43   51417
# Health Care                       75  1614707  21529.426667      75  106114
# ...

# %%
week1 = pd.read_csv("Restaurant - Week 1 Sales.csv")
week2 = pd.read_csv("Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("Restaurant - Customers.csv")
foods = pd.read_csv("Restaurant - Foods.csv")

# %%
pd.concat(objs = [week1,week2],ignore_index = True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
week1.append(other = week2, ignore_index = True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# ..           ...      ...
# 495          783       10
# 496          556       10
# 497          547        9
# 498          252        9
# 499          249        6
#
# [500 rows x 2 columns]

# %%
sales = pd.concat(objs = [week1,week2], keys = ["week1","week2"])

# %%
sales.head()
# Out:
#          Customer ID  Food ID
# week1 0          537        9
#       1           97        4
#       2          658        1
#       3          202        2
#       4          155        9

# %%
sales.loc[("week1",0)]
# Out:
# Customer ID    537
# Food ID          9
# Name: (week1, 0), dtype: int64

# %%
sales.loc[("week1",0),("Customer ID","Food ID")]
# Out:
# Customer ID    537
# Food ID          9
# Name: (week1, 0), dtype: int64

# %%
week1.merge(week2,how = "inner", on = ["Customer ID","Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
merged = week1.merge(week2, how = 'outer', on = "Customer ID", suffixes = ["_Week1","_Week2"],indicator = True)

# %%
merged["_merge"]
# Out:
# 0            both
# 1       left_only
# 2       left_only
# 3       left_only
# 4            both
#           ...
# 449    right_only
# 450    right_only
# 451    right_only
# 452    right_only
# 453    right_only
# Name: _merge, Length: 454, dtype: category
# Categories (3, object): ['left_only', 'right_only', 'both']

# %%
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
merged[merged["_merge"].isin(["left_only","right_only"])]
# Out:
#      Customer ID  Food ID_Week1  Food ID_Week2      _merge
# 1             97            4.0            NaN   left_only
# 2            658            1.0            NaN   left_only
# 3            202            2.0            NaN   left_only
# 6            213            8.0            NaN   left_only
# 7            600            1.0            NaN   left_only
# ..           ...            ...            ...         ...
# 449          855            NaN            4.0  right_only
# 450          559            NaN           10.0  right_only
# 451          276            NaN            4.0  right_only
# 452          556            NaN           10.0  right_only
# 453          252            NaN            9.0  right_only
#
# [392 rows x 4 columns]

# %%
customers.head()
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive
# 3   4     Steven     Evans    Male     Fatz               Registered Nurse
# 4   5       Judy  Morrison  Female  Demivee                Legal Assistant

# %%
week1.merge(customers, how = 'left', left_on = "Customer ID", right_on = "ID").drop("ID",axis = "columns")
# Out:
#      Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0            537        9     Cheryl   Carroll  Female   Zoombeat
# 1             97        4     Amanda   Watkins  Female        Ozu
# 2            658        1    Patrick      Webb    Male  Browsebug
# 3            202        2      Louis  Campbell    Male  Rhynoodle
# 4            155        9    Carolyn      Diaz  Female   Gigazoom
# ..           ...      ...        ...       ...     ...        ...
# 245          413        9      Diane    Bailey  Female    Wikibox
# 246          926        6       Anne    Wagner  Female      Skyba
# 247          134        3      Diana      Hall  Female      Quinu
# 248          396        6       Juan    Romero    Male    Zoonder
# 249          535       10      Nancy       Cox  Female     Trudeo
#
#                         Occupation
# 0                 Registered Nurse
# 1              Account Coordinator
# 2    Community Outreach Specialist
# ...

# %%
satsifaction = pd.read_csv("Restaurant - Week 1 Satisfaction.csv")

# %%
satsifaction.head()
# Out:
#    Satisfaction Rating
# 0                    2
# 1                    7
# 2                    3
# 3                    7
# 4                   10

# %%
week1.join(satsifaction)
# Out:
#      Customer ID  Food ID  Satisfaction Rating
# 0            537        9                    2
# 1             97        4                    7
# 2            658        1                    3
# 3            202        2                    7
# 4            155        9                   10
# ..           ...      ...                  ...
# 245          413        9                    1
# 246          926        6                    2
# 247          134        3                    8
# 248          396        6                   10
# 249          535       10                    3
#
# [250 rows x 3 columns]

# %%
pd.Timestamp('2020-02-02')
# Out:
# Timestamp('2020-02-02 00:00:00')

# %%
dates = pd.Series(["2021-01-01","2020-12-03","Hello"])
pd.to_datetime(dates, errors = "coerce")
# Out:
# 0   2021-01-01
# 1   2020-12-03
# 2          NaT
# dtype: datetime64[ns]

# %%
pd.date_range(start = "2021-01-01", end = "2024-01-01", freq = "A")
# Out:
# DatetimeIndex(['2021-12-31', '2022-12-31', '2023-12-31'], dtype='datetime64[ns]', freq='A-DEC')

# %%
s = pd.date_range(start = "2021-01-01",periods = 20, freq = "M")

# %%
sb = pd.Series(s)

# %%
sb[sb.dt.is_month_end]
# Out:
# 0    2021-01-31
# 1    2021-02-28
# 2    2021-03-31
# 3    2021-04-30
# 4    2021-05-31
# 5    2021-06-30
# 6    2021-07-31
# 7    2021-08-31
# 8    2021-09-30
# 9    2021-10-31
# 10   2021-11-30
# 11   2021-12-31
# 12   2022-01-31
# 13   2022-02-28
# 14   2022-03-31
# 15   2022-04-30
# 16   2022-05-31
# 17   2022-06-30
# 18   2022-07-31
# 19   2022-08-31
# dtype: datetime64[ns]

# %%
"!".join(["a","b","c"])
# Out:
# 'a!b!c'

# %%
.to_csv("abc.csv", index = False)

# %%
pd.ExcelWriter("abc.xlsx")

# %%
.to_excel()

# %%
excel_file.save()

# %%
.plot(kind="pie",legend = True)
.plot(kind="line",legend = True)
.plot(kind="barh",legend = True)

# %%
plt.style.available

# %%
# %matlplotlib inline

# %%
pd.options.display.max_rows = 18

# %%
pd.set_option("max_rows",16)

# %%
pd.set_option("precision",2)
